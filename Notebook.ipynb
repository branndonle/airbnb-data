# %%
import pandas as pd

# %%
data = pd.read_csv('dataset/Airbnb_Open_Data.csv')
data.head()
# Out:
# C:\Users\Brandon\AppData\Local\Temp\ipykernel_9336\1982176433.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('dataset/Airbnb_Open_Data.csv')
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# ...

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
"""Deleting Redundant columns.
Renaming the columns.
Dropping duplicates.
Cleaning Individual Columns
Remove NaN values from dataset
Check for some more transformations."""
# Out:
# 'Deleting Redundant columns.\nRenaming the columns.\nDropping duplicates.\nCleaning Individual Columns\nRemove NaN values from dataset\nCheck for some more transformations.'

# %%
#Deleting Redundant Columns (2 ways to do this)
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
columns_to_drop = ['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license', 'id']

columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']

# %%
len(columns_to_drop)
# Out:
# 7

# %%
len(columns_to_keep)
# Out:
# 19

# %% [markdown]
# # Dropping Columns
# ## 1st Method, Filtering Data

# %%
data[columns_to_keep]
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df = data[columns_to_keep]
df.shape
# Out:
# (102599, 19)

# %% [markdown]
# ## 2nd Method, Dropping Columns

# %%
data.columns
#data.drop(columns=['license']) #if you do it like this, it won't save the new dataframe so what you have to do this:
#data = data.drop(columns=columns_to_drop) OR
data.drop(columns=columns_to_drop, inplace=True) #this reduces the columns from 26 to 19

# %%
data.shape
# Out:
# (102599, 19)

# %%
data
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %% [markdown]
# # Renaming the columns

# %%
data.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
data.rename(columns={"NAME": "Name"}, inplace=True)

# %%
data.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
# Reformatting the column names to all uppercase
new_column_names = []
for i in data.columns:
    new_column_names.append((i.upper()))

# %%
type(new_column_names)
# Out:
# list

# %%
#Creating a new dataframe so that we can set the "new_column_names" variable to new dataframe columns
new_df_to_modify = data.copy()

# %%
#Set new column names with UPPERCASE to the new dataframe
new_df_to_modify.columns = new_column_names

# %%
# New dataframe with uppercase columns
new_df_to_modify.columns
# Out:
# Index(['NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS', 'LAST REVIEW'],
#       dtype='object')

# %% [markdown]
# # Removing Duplicates

# %%
#You can find the number of duplicates by doing:
#data.duplicated().sum()
#You can display the first five records by doing:
# data.duplicated().head()
#You can display the last five records by doing:

#data.duplicated().tail()

#This displays the number of falses and trues.
#data.duplicated().value_counts()

# %% [markdown]
# ## You want to see how many duplicate entries there are.

# %%
data.duplicated().sum()
# Out:
# 541

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Removing NaN or N/A values from columns

# %%
#Finding the number of N/A values
data.isna().sum()
# Out:
# Name                        250
# host id                       0
# host_identity_verified      289
# host name                   404
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# Construction year           214
# price                       247
# service fee                 273
# minimum nights              400
# number of reviews           183
# last review               15832
# dtype: int64

# %%
data.drop(columns=['last review'], inplace=True)

# %%
data.isna().sum()
# Out:
# Name                      250
# host id                     0
# host_identity_verified    289
# host name                 404
# neighbourhood group        29
# neighbourhood              16
# lat                         8
# long                        8
# country                   532
# country code              131
# instant_bookable          105
# cancellation_policy        76
# room type                   0
# Construction year         214
# price                     247
# service fee               273
# minimum nights            400
# number of reviews         183
# dtype: int64

# %%
#Drops the N/a values from the column and saves it
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Name                      0
# host id                   0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# lat                       0
# long                      0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# Construction year         0
# price                     0
# service fee               0
# minimum nights            0
# number of reviews         0
# dtype: int64

# %% [markdown]
# # Cleaning Individual Columns

# %%
#This sets the column values to all uppercase
data['host_identity_verified'].str.upper()
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 4            VERIFIED
# 5            VERIFIED
# 7         UNCONFIRMED
#              ...
# 102029    UNCONFIRMED
# 102030       VERIFIED
# 102031       VERIFIED
# 102032    UNCONFIRMED
# 102040       VERIFIED
# Name: host_identity_verified, Length: 99342, dtype: object

# %%
# This saves the uppercase column values to the dataframe.
data['host_identity_verified'] = data['host_identity_verified'].str.upper()

# %%
data
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
data['instant_bookable'].apply(lambda x: 1 if x == True else 0)
# Out:
# 0         0
# 1         0
# 4         0
# 5         1
# 7         0
#          ..
# 102029    0
# 102030    1
# 102031    1
# 102032    0
# 102040    1
# Name: instant_bookable, Length: 99342, dtype: int64

# %%
data['instant_bookable'] = data['instant_bookable'].apply(lambda x: 1 if x == True else 0)

# %%
data
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
type(data['instant_bookable'][5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# h:\Users\Brandon\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# h:\Users\Brandon\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# h:\Users\Brandon\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 15
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
#This resets the index of each row. In the table above, it goes from 0 to 1 to 4 and then 5 and 7.
data.reset_index(inplace=True)

# %%
type(data['instant_bookable'][15])
# Out:
# numpy.int64

# %% [markdown]
# # Check for some more Transformations

# %%
# We want to get rid of the dollar signs in the columns price and service feed,
# and convert thme to integers
type(data['price'][15])
# Out:
# str

# %%
#Display the first 3 rows
data['price'].head(3)
# Out:
# 0    $966
# 1    $142
# 2    $204
# Name: price, dtype: object

# %%
#Replace the dollar signs with space and then save it to df
data['price'] = data['price'].str.replace("$", " ")
# Out:
# C:\Users\Brandon\AppData\Local\Temp\ipykernel_9336\2381529013.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['price'] = data['price'].str.replace("$", " ")

# %%
#Replace the commas with space and then save it to df
data['price'] = data['price'].str.replace(",", "")

# %%
data['price'][15]
# Out:
# ' 1020 '

# %%
data['price'] = data['price'].str.replace(" ", "")

# %%
data['price'][15]
# Out:
# '1020'

# %%
#Changes the type from str to int and saves it
data['price'] = data['price'].astype(int)

# %%
type(data['price'][15])
# Out:
# numpy.int32

# %%
#If I want the dataset to be a csv file, you can do:
data.to_csv("Cleaned_data.csv")

# %%
pd.read_csv("Cleaned_data.csv")
# Out:
#        Unnamed: 0   index                                              Name  \
# 0               0       0                Clean & quiet apt home by the park
# 1               1       1                             Skylit Midtown Castle
# 2               2       4  Entire Apt: Spacious Studio/Loft by central park
# 3               3       5         Large Cozy 1 BR Apartment In Midtown East
# 4               4       7                                   BlissArtsSpace!
# ...           ...     ...                                               ...
# 99337       99337  102029            Cozy room in a 2B with backyard access
# 99338       99338  102030                      An East Williamsburg Delight
# 99339       99339  102031                      Cozy bedroom in williamsburg
# 99340       99340  102032                            Spacious Room w/ 2 Bed
# 99341       99341  102040                     Room in Queens, NY, near LGA.
#
# ...

# %%
#Removes the index column like the one above this cell
data.drop(columns=['index'], inplace=True)

# %%
#This creates a csv file without the index column
data.to_csv("Cleaned_data_wo_index", index=False)

# %%
pd.read_csv("Cleaned_data_wo_index")
# Out:
#                                                    Name      host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       host_identity_verified  host name neighbourhood group  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
data.to_excel("Excel_cleaned_data.xlsx")

# %%
data.to_excel("Excel_cleaned_data_index_false.xlsx", index=False)

# %%
pd.read_excel("Excel_cleaned_data.xlsx")
# Out:
#        Unnamed: 0                                              Name  \
# 0               0                Clean & quiet apt home by the park
# 1               1                             Skylit Midtown Castle
# 2               2  Entire Apt: Spacious Studio/Loft by central park
# 3               3         Large Cozy 1 BR Apartment In Midtown East
# 4               4                                   BlissArtsSpace!
# ...           ...                                               ...
# 99337       99337            Cozy room in a 2B with backyard access
# 99338       99338                      An East Williamsburg Delight
# 99339       99339                      Cozy bedroom in williamsburg
# 99340       99340                            Spacious Room w/ 2 Bed
# 99341       99341                     Room in Queens, NY, near LGA.
#
#            host id host_identity_verified  host name neighbourhood group  \
# 0      80014485718            UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
pd.read_excel("Excel_cleaned_data_index_false.xlsx")
# Out:
#                                                    Name      host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       host_identity_verified  host name neighbourhood group  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...
